# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## 1. Creating a Sample of "tls201" table

# %%
data_folder = './data/data_PATSTAT_Global_2018_Autumn_01/'

# %%
df = pd.read_csv(data_folder+'tls201_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    appln_id appln_auth  appln_nr appln_kind appln_filing_date  \
# 0         0         XX       NaN         D         9999-12-31
# 1         1         EP  103094.0         A         2000-02-15
# 2         2         EP  107845.0         A         1992-12-02
# 3         3         EP  202556.0         A         2000-07-17
# 4         4         EP  300208.0         A         2000-01-13
#
#    appln_filing_year appln_nr_epodoc appln_nr_original ipr_type  \
# 0               9999             NaN               NaN       PI
# 1               2000   EP20000103094          00103094       PI
# 2               1992   EP20000107845          00107845       PI
# 3               2000   EP20000202556          00202556       PI
# 4               2000   EP20000300208          00300208       PI
#
#   receiving_office  ...  earliest_publn_date earliest_publn_year  \
# 0                   ...           9999-12-31                9999
# 1                   ...           2000-09-20                2000
# ...

# %%
df.columns
# Out:
# Index(['appln_id', 'appln_auth', 'appln_nr', 'appln_kind', 'appln_filing_date',
#        'appln_filing_year', 'appln_nr_epodoc', 'appln_nr_original', 'ipr_type',
#        'receiving_office', 'internat_appln_id', 'int_phase', 'reg_phase',
#        'nat_phase', 'earliest_filing_date', 'earliest_filing_year',
#        'earliest_filing_id', 'earliest_publn_date', 'earliest_publn_year',
#        'earliest_pat_publn_id', 'granted', 'docdb_family_id',
#        'inpadoc_family_id', 'docdb_family_size', 'nb_citing_docdb_fam',
#        'nb_applicants', 'nb_inventors'],
#       dtype='object')

# %%
df.to_csv(data_folder+'tls201_part01.txt', encoding='utf-8', index=False)

# %% [markdown]
# ## 2. Creating a sample of "tls209" table:

# %%
data_folder = './data/data_PATSTAT_Global_2018_Autumn/'

# %%
df = pd.read_csv(data_folder+'tls209_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    appln_id ipc_class_symbol ipc_class_level ipc_version ipc_value  \
# 0         1      G06K   7/00               A  2006-01-01         I
# 1         1      G06K  17/00               A  2006-01-01         I
# 2         1     G06K  19/077               A  2006-01-01         I
# 3         1      H01R  12/18               A  2006-01-01         I
# 4         1      H04M   1/02               A  2006-01-01         I
#
#   ipc_position ipc_gener_auth
# 0            L             EP
# 1            L             JP
# 2            F             JP
# 3            L             JP
# 4            L             JP

# %%
df.to_csv(data_folder+'tls209_part01.txt', encoding='utf-8', index=False)

# %% [markdown]
# ## 3. Creating a sample of "tls204" table: Priority patents

# %%
data_folder = './data/data_PATSTAT_Global_2018_Autumn/'

# %%
df = pd.read_csv(data_folder+'tls204_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    appln_id  prior_appln_id  prior_appln_seq_nr
# 0         1        18546269                   1
# 1         2        23057720                   1
# 2         2        23057723                   2
# 3         2        23068531                   3
# 4         2        23068585                   4

# %%
df.to_csv(data_folder+'tls204_part01.txt', encoding='utf-8', index=False)

# %% [markdown]
# ## 4. Creating a sample of "tls207":
# ## Lists the correspondence between patent application and inventors (applicants)

# %%
data_folder = './data/data_PATSTAT_Global_2018_Autumn/'

# %%
df = pd.read_csv(data_folder+'tls207_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    person_id  appln_id  applt_seq_nr  invt_seq_nr
# 0          1         1             1            0
# 1          1         7             1            0
# 2          1        46             1            0
# 3          1       775             1            0
# 4          1      1192             1            0

# %%
df.to_csv(data_folder+'tls207_part01.txt', encoding='utf-8', index=False)

# %% [markdown]
# ## 5. Creating a sample of "tls206":
# ## Provides details on names and addresses of applicants

# %%
data_folder = './data/data_PATSTAT_Global_2018_Autumn/'

# %%
df = pd.read_csv(data_folder+'tls206_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    person_id        person_name                          person_address  \
# 0          1  Nokia Corporation            Keilalahdentie 4,02150 Espoo
# 1          2   Lipponen, Markku   Simo Kaarion katu 1 A 2,33720 Tampere
# 2          3     Laitinen, Timo               Peiponkatu 6,37830 Viiala
# 3          4           Aho, Ari     Elementinpolku 13 A 6,33720 Tampere
# 4          5    Knuutila, Jarno  Matti Tapion katu 1 F 17,33720 Tampere
#
#   person_ctry_code  doc_std_name_id     doc_std_name    psn_id  \
# 0               FI                1       NOKIA CORP  21102785
# 1               FI                2  LIPPONEN MARKKU  17447396
# 2               FI                3    LAITINEN TIMO  16471985
# 3               FI                4          AHO ARI    327970
# 4               FI                5   KNUUTILA JARNO  15446602
#
#             psn_name  psn_level psn_sector
# 0  NOKIA CORPORATION          2    COMPANY
# 1   LIPPONEN, MARKKU          0        NaN
# ...

# %%
df.to_csv(data_folder+'tls206_part01.txt', encoding='utf-8', index=False)

# %% [markdown]
# ## 6. Creating a sample of "tls211":
# ## Information on the patent offices of destination (publication authorities) of all INPADOC family members and excludes the PCT publication authority (WO)

# %%
data_folder = './data/data_PATSTAT_Global_2018_Autumn/'

# %%
df = pd.read_csv(data_folder+'tls211_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    pat_publn_id publn_auth   publn_nr  publn_nr_original publn_kind  appln_id  \
# 0             0         XX        NaN                NaN                    0
# 1           777         EP  1943895.0                NaN         A1       776
# 2           779         EP  1943896.0                NaN         A1       778
# 3           781         EP  1943898.0                NaN         A1       780
# 4           783         EP  1943899.0                NaN         A1       782
#
#    publn_date publn_lg publn_first_grant  publn_claims
# 0  9999-12-31                          N             0
# 1  2008-07-16       de                 N            14
# 2  2008-07-16       de                 N             9
# 3  2008-07-16       de                 N            23
# 4  2008-07-16       de                 N            22

# %%
type(df.iloc[0,4])
# Out:
# str

# %%
df.to_csv(data_folder+'tls211_part01.txt', encoding='utf-8', index=False)

# %% [markdown]
# ## 6. Creating a sample of "tls212": Citations

# %%
data_folder = './data/data_PATSTAT_Global_2018_Autumn/'

# %%
df = pd.read_csv(data_folder+'tls212_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    pat_publn_id  citn_replenished  citn_id citn_origin  cited_pat_publn_id  \
# 0           777                 0        1         SEA           291624782
# 1           777                 0        2         SEA           288782234
# 2           777                 0        3         SEA           281909471
# 3           777                 0        4         SEA           282097442
# 4           777                 0        5         SEA           303136841
#
#    cited_appln_id  pat_citn_seq_nr  cited_npl_publn_id  npl_citn_seq_nr  \
# 0               0                1                   0                0
# 1               0                2                   0                0
# 2               0                3                   0                0
# 3               0                4                   0                0
# 4               0                5                   0                0
#
#   citn_gener_auth
# 0              EP
# 1              EP
# 2              EP
# ...

# %% [markdown]
# ## 7. Creating a sample of "tls203": Application Abstract

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls203_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    appln_id appln_abstract_lg  \
# 0         1                en
# 1         2                en
# 2         3                en
# 3         4                en
# 4         5                en
#
#                                       appln_abstract
# 0  A mobile station (MS) that comprises an interf...
# 1  Methods are disclosed for the production of an...
# 2  The detector includes scintillators (S1 to S5)...
# 3  The specification describes techniques for wir...
# 4  The specification describes source/drain conta...

# %% [markdown]
# ## 8. Creating a sample of "tls205": Technical Relation

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls205_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    appln_id  tech_rel_appln_id
# 0         8           31308284
# 1       159           48940218
# 2       159           51019180
# 3       159           51022388
# 4       159           51022511

# %% [markdown]
# ## 9. Creating a sample of "tls210": National Classification

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls210_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    appln_id nat_class_symbol
# 0    379100    G2J JGFG JGFG
# 1    448592  NOT CLASSIFIED
# 2    448593  NOT CLASSIFIED
# 3    448594  NOT CLASSIFIED
# 4    448595  NOT CLASSIFIED

# %% [markdown]
# ## 10. Creating a sample of "tls214": Non patent literature publication

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls214_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    npl_publn_id npl_type                                         npl_biblio  \
# 0             0                                                         NaN
# 1             1        w  ERICKSON S.J. ET AL.: 'Time- and Frequency-Dom...
# 2             4        e  DATABASE GENBANK 13 January 2009 (2009-01-13),...
# 3             5        s  'Klima un Energie', SPEKTRUM DER WISSENSCHAFT,...
# 4             7        s  LIANG P; ZHANG H; WANG G; LI S; CONG S; LUO Y ...
#
#                                           npl_author  \
# 0                                                NaN
# 1                               ERICKSON S.J. ET AL.
# 2                                      ALMEIDA-KING.
# 3                                                NaN
# 4  LIANG P; ZHANG H; WANG G; LI S; CONG S; LUO Y ...
#
#                                           npl_title1  \
# 0                                                NaN
# 1  Time- and Frequency-Domain Measurements for an...
# ...

# %%
df.columns
# Out:
# Index(['npl_publn_id', 'npl_type', 'npl_biblio', 'npl_author', 'npl_title1',
#        'npl_title2', 'npl_editor', 'npl_volume', 'npl_issue', 'npl_publn_date',
#        'npl_publn_end_date', 'npl_publisher', 'npl_page_first',
#        'npl_page_last', 'npl_abstract_nr', 'npl_doi', 'npl_isbn', 'npl_issn',
#        'online_availability', 'online_classification', 'online_search_date'],
#       dtype='object')

# %% [markdown]
# ## 11. Creating a sample of "tls215": Citation Category

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls215_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    pat_publn_id  citn_replenished  citn_id citn_categ
# 0           777                 0        1          X
# 1           777                 0        2          X
# 2           777                 0        3          A
# 3           777                 0        4          A
# 4           777                 0        5          A

# %% [markdown]
# ## 12. Creating a sample of "tls216": Application Continuation

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls216_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    appln_id  parent_appln_id contn_type
# 0         2         16976929        DIV
# 1        37         15799021        DIV
# 2        57         15774456        DIV
# 3       109         15956295        DIV
# 4       152         15907068        DIV

# %% [markdown]
# ## 13. Creating a sample of "tls222": Japanese Classification

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls222_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    appln_id jp_class_scheme     jp_class_symbol
# 0  24934700              FI  4F24F11 /02   101A
# 1  24934700              FI  4F24F11 /02   101D
# 2  24934700              FI   4F24F11 /41   110
# 3  24934700              FI         4F24F11 /43
# 4  24934700              FI  4F25D21 /08      A

# %% [markdown]
# ## 14. Creating a sample of "tls223": US Classification

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls223_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    appln_id docus_class_symbol
# 0    448453         514357000P
# 1    448453         514408000S
# 2    448453         514649000S
# 3    448453         514674000S
# 4    448454         514256000P

# %% [markdown]
# ## 15. Creating a sample of "tls226": Unmodified Person Data

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls226_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    person_orig_id  person_id source  source_version      name_freeform  \
# 0               1          1  EPREG             NaN  Nokia Corporation
# 1               2          2  EPREG             NaN   Lipponen, Markku
# 2               3          3  EPREG             NaN     Laitinen, Timo
# 3               4          4  EPREG             NaN           Aho, Ari
# 4               5          5  EPREG             NaN    Knuutila, Jarno
#
#    last_name  first_name  middle_name  address_freeform  \
# 0        NaN         NaN          NaN               NaN
# 1        NaN         NaN          NaN               NaN
# 2        NaN         NaN          NaN               NaN
# 3        NaN         NaN          NaN               NaN
# 4        NaN         NaN          NaN               NaN
#
#                   address_1      address_2  address_3  address_4  address_5  \
# 0          Keilalahdentie 4    02150 Espoo        NaN        NaN        NaN
# ...

# %%
len(df.columns)
# Out:
# 21

# %% [markdown]
# ## 16. Creating a sample of "tls227": Link Between Person and Publication

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls227_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    person_id  pat_publn_id  applt_seq_nr  invt_seq_nr
# 0          1          6460             1            0
# 1          1         43605             1            0
# 2          1         51584             1            0
# 3          1         51596             1            0
# 4          1         51639             1            0

# %% [markdown]
# ## 17. Creating a sample of "tls229": Industry Classification

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls229_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    appln_id  nace2_code    weight
# 0         1       26.30  0.500000
# 1         1       27.33  0.125000
# 2         1       28.23  0.375000
# 3         2       21.00  0.789474
# 4         2       26.50  0.210526

# %% [markdown]
# ## 18. Creating a sample of "tls230": Classification by Technical Field

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls230_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    appln_id  techn_field_nr  weight
# 0         1               1   0.125
# 1         1               3   0.500
# 2         1               6   0.375
# 3         2              11   0.200
# 4         2              15   0.800

# %% [markdown]
# ## 19. Creating a sample of "tls231": Legal Event

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df_1 = pd.read_csv(data_folder+'tls231_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df_1.head()
# Out:
#    event_id  appln_id  event_seq_nr event_type event_auth event_code  \
# 0         1    743860             1                    AT        A1B
# 1         2    845889             1                    AT       A1AW
# 2         3    577033             1                    AT        A1Z
# 3         4    653056             1                    AT        A1J
# 4         5    653056             2                    AT       A1WE
#
#   event_filing_date event_publn_date event_effective_date  event_text  \
# 0        9999-12-31       1971-10-15           9999-12-31         NaN
# 1        9999-12-31       1969-04-15           9999-12-31         NaN
# 2        9999-12-31       1969-12-15           9999-12-31         NaN
# 3        9999-12-31       1969-08-15           9999-12-31         NaN
# 4        9999-12-31       1969-10-15           9999-12-31         NaN
#
#   ref_doc_auth  ref_doc_nr ref_doc_kind ref_doc_date  ref_doc_text  \
# ...

# %%
pf.merge(df_1, df_, on=['event_code'])
# Out:
#        event_id  appln_id  event_seq_nr event_type event_auth event_code  \
# 5220       5252   1118855             1                    AT         XX
# 6203      26174    653530             1                    AT         EN
# 6428      26987    853412             1                    AT         EN
# 8369      29119    885875             3                    AT         EN
# 12063     33138    831383             2                    AT         EN
# 15161     36506    736895             1                    AT         EN
# 15722     37107    615389             4                    AT         EN
# 20238     41979    617971             1                    AT         EN
#
#       event_filing_date event_publn_date event_effective_date  event_text  \
# 5220         9999-12-31       1991-01-15           9999-12-31         NaN
# 6203         9999-12-31       1981-07-15           9999-12-31         NaN
# 6428         9999-12-31       1983-03-15           9999-12-31         NaN
# ...

# %%
df[df.event_code=='A1B']
# Out:
#      event_auth event_code event_impact                        event_descr  \
# 6            AT        A1B                                      CORRECTION
# 2944         NL        A1B            +  A SEARCH REPORT HAS BEEN DRAWN UP
#
#                                        event_descr_orig event_category_code  \
# 6                                          BERICHTIGUNG
# 2944  RUBRIEK A ONDERDEEL 1 HET RESULTAAT VAN EEN ON...                   D
#
#         event_category_title
# 6                        NaN
# 2944  SEARCH AND EXAMINATION

# %% [markdown]
# ## 20. Creating a sample of "tls801": Reference table of country codes

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls801_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#   ctry_code iso_alpha3              st3_name state_indicator      continent  \
# 0                                    unknown                            NaN
# 1        AD        AND               Andorra               Y         Europe
# 2        AE        ARE  United Arab Emirates               Y           Asia
# 3        AF        AFG           Afghanistan               Y           Asia
# 4        AG        ATG  Antigua and Barbados               Y  North America
#
#   eu_member epo_member oecd_member discontinued
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## 21. Creating a sample of "tls803": Reference table of legal event codes

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls803_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#   event_auth event_code event_impact  \
# 0         AR         FA            -
# 1         AR         FB            -
# 2         AR         FC            -
# 3         AR         FD            -
# 4         AR         FG            +
#
#                                          event_descr  \
# 0                          ABANDONMENT OR WITHDRAWAL
# 1                   SUSPENSION OF GRANTING PROCEDURE
# 2                                            REFUSAL
# 3  APPLICATION DECLARED VOID OR LAPSED, E.G., DUE...
# 4                                GRANT, REGISTRATION
#
#                                     event_descr_orig event_category_code  \
# 0                                  ABANDONO O RETIRO                   B
# 1                SUSPENSION DEL PROCESO DE CONCESION                   T
# 2                                         DENEGACION                   B
# 3  SOLICITUD DECLARADA NULA O CADUCADA, POR EJEMP...                   B
# ...

# %%
df[df.event_category_code=='F'].event_code.head(10)
# Out:
# 4        FG
# 111      UW
# 133      CW
# 140      FF
# 141     FGA
# 142     FGD
# 143     FGF
# 144     FGI
# 264    B09Y
# 300    B15J
# Name: event_code, dtype: object

# %% [markdown]
# ## 22. Creating a sample of "tls901": Mapping between technology fields and IPC

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls901_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#   ipc_maingroup_symbol  techn_field_nr            techn_sector  \
# 0                 A01B              29  Mechanical engineering
# 1                 A01C              29  Mechanical engineering
# 2                 A01D              29  Mechanical engineering
# 3                 A01F              29  Mechanical engineering
# 4                 A01G              29  Mechanical engineering
#
#               techn_field
# 0  Other special machines
# 1  Other special machines
# 2  Other special machines
# 3  Other special machines
# 4  Other special machines

# %% [markdown]
# ## 23. Creating a sample of "tls902": Mapping between IPC and industrial sectors

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls902_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#     ipc not_with_ipc unless_with_ipc nace2_code  nace2_weight  \
# 0  A01B          NaN             NaN       28.3             1
# 1  A01C          NaN             NaN       28.3             1
# 2  A01D          NaN             NaN       28.3             1
# 3  A01F          NaN             NaN       28.3             1
# 4  A01G          NaN             NaN       28.3             1
#
#                                          nace2_descr
# 0  Manufacture of Agricultural and Forestry Machi...
# 1  Manufacture of Agricultural and Forestry Machi...
# 2  Manufacture of Agricultural and Forestry Machi...
# 3  Manufacture of Agricultural and Forestry Machi...
# 4  Manufacture of Agricultural and Forestry Machi...

# %% [markdown]
# ## 24. Creating a sample of "tls904": NUTS regional codes

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls904_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#     nuts  nuts_level nuts_label
# 0     AL           0  SHQIPËRIA
# 1    AL0           1  SHQIPËRIA
# 2   AL01           2       Veri
# 3  AL011           3      Dibër
# 4  AL012           3     Durrës

# %% [markdown]
# ## 25. Creating a sample of "tls906": Person

# %%
data_folder = '../../patstat_2018_backup/openPatstat/data/data_PATSTAT_Global_2018_Autumn/'

df = pd.read_csv(data_folder+'tls906_part01.txt.gz', compression='gzip', low_memory=False, nrows=100000)
df.head()
# Out:
#    person_id        person_name                          person_address  \
# 0          1  Nokia Corporation            Keilalahdentie 4,02150 Espoo
# 1          2   Lipponen, Markku   Simo Kaarion katu 1 A 2,33720 Tampere
# 2          3     Laitinen, Timo               Peiponkatu 6,37830 Viiala
# 3          4           Aho, Ari     Elementinpolku 13 A 6,33720 Tampere
# 4          5    Knuutila, Jarno  Matti Tapion katu 1 F 17,33720 Tampere
#
#   person_ctry_code   nuts  nuts_level  doc_std_name_id     doc_std_name  \
# 0               FI  FI1B1           3                1       NOKIA CORP
# 1               FI  FI197           3                2  LIPPONEN MARKKU
# 2               FI  FI197           3                3    LAITINEN TIMO
# 3               FI  FI197           3                4          AHO ARI
# 4               FI  FI197           3                5   KNUUTILA JARNO
#
#      psn_id           psn_name  psn_level psn_sector     han_id  \
# ...
